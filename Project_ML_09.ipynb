# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns

# %%
df2009 = pd.read_csv("https://raw.githubusercontent.com/rahulchowdary01/wales-clustering/main/2009.csv")
df2010 = pd.read_csv("https://raw.githubusercontent.com/rahulchowdary01/wales-clustering/main/2010.csv")
df2011 = pd.read_csv("https://raw.githubusercontent.com/rahulchowdary01/wales-clustering/main/2011.csv")
df2012 = pd.read_csv("https://raw.githubusercontent.com/rahulchowdary01/wales-clustering/main/2012.csv")
df2013 = pd.read_csv("https://raw.githubusercontent.com/rahulchowdary01/wales-clustering/main/2013.csv")
df2014 = pd.read_csv("https://raw.githubusercontent.com/rahulchowdary01/wales-clustering/main/2014.csv")
df2015 = pd.read_csv("https://raw.githubusercontent.com/rahulchowdary01/wales-clustering/main/2015.csv")
df2016 = pd.read_csv("https://raw.githubusercontent.com/rahulchowdary01/wales-clustering/main/2016.csv")
df2017 = pd.read_csv("https://raw.githubusercontent.com/rahulchowdary01/wales-clustering/main/2017.csv")
df2018 = pd.read_csv("https://raw.githubusercontent.com/rahulchowdary01/wales-clustering/main/2018.csv")

# %%
df2009.head()
# Out:
#         Unnamed: 0                                      Unnamed: 1   Wales
# 0  All industries                                              NaN  1336300
# 1  All industries               Agriculture, forestry and fishing     37700
# 2              NaN                                     Production    156700
# 3              NaN                                   Construction     96600
# 4              NaN  Wholesale, retail, transport, hotels and food    345400

# %% [markdown]
# #Data cleaning

# %%
df2009.shape
# Out:
# (11, 3)

# %%
df2009_1 = df2009.iloc[1:,1:]
df2010_1 = df2010.iloc[1:,1:]
df2011_1 = df2011.iloc[1:,1:]
df2012_1 = df2012.iloc[1:,1:]
df2013_1 = df2013.iloc[1:,1:]
df2014_1 = df2014.iloc[1:,1:]
df2015_1 = df2015.iloc[1:,1:]
df2016_1 = df2016.iloc[1:,1:]
df2017_1 = df2017.iloc[1:,1:]
df2018_1 = df2018.iloc[1:,1:]

# %%
df2009_1.head()
# Out:
#                                        Unnamed: 1  Wales
# 1              Agriculture, forestry and fishing    37700
# 2                                     Production   156700
# 3                                   Construction    96600
# 4  Wholesale, retail, transport, hotels and food   345400
# 5                  Information and communication    27800

# %% [markdown]
# #concat

# %%
df= pd.concat([df2009_1, df2010_1 ,df2011_1, df2012_1 ,df2013_1, df2014_1 ,df2015_1, df2016_1,df2017_1, df2018_1 ], ignore_index = True, axis = 1)
df.head()
# Out:
#                                                0       1   \
# 1              Agriculture, forestry and fishing    37700
# 2                                     Production   156700
# 3                                   Construction    96600
# 4  Wholesale, retail, transport, hotels and food   345400
# 5                  Information and communication    27800
#
#                                                2       3   \
# 1              Agriculture, forestry and fishing    38200
# 2                                     Production   149800
# 3                                   Construction    93200
# 4  Wholesale, retail, transport, hotels and food   344500
# 5                  Information and communication    27900
#
#                                                4       5   \
# 1              Agriculture, forestry and fishing    36100
# 2                                     Production   158600
# 3                                   Construction    90000
# ...

# %%
df.shape
# Out:
# (10, 20)

# %%
final_df=df.drop(columns = [2,4,6,8,10,12,14,16,18],axis = 1)
final_df.rename(columns={0:'Industry',1:'2009',3:'2010', 5:'2011',7:'2012',9:'2013',11:'2014',13:'2015',15:'2016',17:'2017',19:'2018'}, inplace=True)
final_df
# Out:
#                                              Industry    2009    2010    2011  \
# 1                  Agriculture, forestry and fishing    37700   38200   36100
# 2                                         Production   156700  149800  158600
# 3                                       Construction    96600   93200   90000
# 4      Wholesale, retail, transport, hotels and food   345400  344500  343100
# 5                      Information and communication    27800   27900   26400
# 6                   Finance and insurance activities    33800   29800   33200
# 7                             Real estate activities    13500   14600   17600
# 8   Professional, scientific and technical activit...  144800  145800  143600
# 9   Public administration, defence, education and ...  415600  418600  425600
# 10                          Other service activities    64200   68000   72400
#
#       2012    2013    2014    2015    2016    2017    2018
# ...

# %%
final_df.shape
# Out:
# (10, 11)

# %%
final_df.isnull()
# Out:
#     Industry   2009   2010   2011   2012   2013   2014   2015   2016   2017  \
# 1      False  False  False  False  False  False  False  False  False  False
# 2      False  False  False  False  False  False  False  False  False  False
# 3      False  False  False  False  False  False  False  False  False  False
# 4      False  False  False  False  False  False  False  False  False  False
# 5      False  False  False  False  False  False  False  False  False  False
# 6      False  False  False  False  False  False  False  False  False  False
# 7      False  False  False  False  False  False  False  False  False  False
# 8      False  False  False  False  False  False  False  False  False  False
# 9      False  False  False  False  False  False  False  False  False  False
# 10     False  False  False  False  False  False  False  False  False  False
#
#      2018
# 1   False
# 2   False
# 3   False
# 4   False
# 5   False
# 6   False
# 7   False
# 8   False
# 9   False
# 10  False

# %%
mean=final_df.mean()
m_df=final_df.fillna(mean)
m_df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
#                                              Industry    2009    2010    2011  \
# 1                  Agriculture, forestry and fishing    37700   38200   36100
# 2                                         Production   156700  149800  158600
# 3                                       Construction    96600   93200   90000
# 4      Wholesale, retail, transport, hotels and food   345400  344500  343100
# 5                      Information and communication    27800   27900   26400
# 6                   Finance and insurance activities    33800   29800   33200
# 7                             Real estate activities    13500   14600   17600
# ...

# %% [markdown]
# #Boxplot

# %%
data=m_df[['2009','2010','2011','2012','2013',"2014","2015","2016","2017","2018"]]
plt.boxplot(data)
plt.show()

# %% [markdown]
# #rename

# %%
sns.boxplot(data=m_df)
fig=plt.gcf()

# %%
m_df["Industry"]= m_df["Industry"].replace({   'Finance and insurance activities ': 'Finance','Wholesale, retail, transport, hotels and food ': 'Retail','Agriculture, forestry and fishing ': 'Agriculture' ,'Public administration, defence, education and health ': 'Public_Adminstration', 'Other service activities ': 'Other_Service',
                                               'Professional, scientific and technical activities; administrative and support service activities ' : 'Professional_Service',
                                               'administrative and support service activities ': 'Professional_Service'})
df1 = m_df
df1
# Out:
#                           Industry    2009    2010    2011    2012    2013  \
# 1                      Agriculture   37700   38200   36100   36100   36800
# 2                      Production   156700  149800  158600  154400  164200
# 3                    Construction    96600   93200   90000   91300   89300
# 4                           Retail  345400  344500  343100  347300  345100
# 5   Information and communication    27800   27900   26400   27200   26900
# 6                          Finance   33800   29800   33200   31100   32400
# 7          Real estate activities    13500   14600   17600   18800   18000
# 8             Professional_Service  144800  145800  143600  137300  149900
# 9             Public_Adminstration  415600  418600  425600  421000  427000
# 10                   Other_Service   64200   68000   72400   72800   75500
#
#       2014    2015    2016    2017    2018
# 1    42700   40700   43200   40200   41100
# 2   173300  172300  162500  165100  165700
# ...

# %% [markdown]
# #Total no of Employee’s

# %%
#sum of total employees in each field
df1['Total employees'] = df1.sum(axis = 1)
df1
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#                           Industry    2009    2010    2011    2012    2013  \
# 1                      Agriculture   37700   38200   36100   36100   36800
# 2                      Production   156700  149800  158600  154400  164200
# 3                    Construction    96600   93200   90000   91300   89300
# 4                           Retail  345400  344500  343100  347300  345100
# 5   Information and communication    27800   27900   26400   27200   26900
# 6                          Finance   33800   29800   33200   31100   32400
# 7          Real estate activities    13500   14600   17600   18800   18000
# 8             Professional_Service  144800  145800  143600  137300  149900
# ...

# %%
# ploting the graph for total employees for each industry over the period
plt.bar(x = df1['Industry'], height= df1['Total employees'])
plt.rcParams['figure.figsize'] = [24,8]
plt.title("Total number of employee’s over the period vs industries")
plt.xlabel('Industry')
plt.ylabel("Employee's count from 2009 to 2018")
plt.grid(True)

# %%
sns.pairplot(df1,hue='Industry')

# %% [markdown]
# #Which Industry has much growth

# %%
# calculating the percentage change for each year and calculating the total percentage over the period
pergrowth_df = df1.drop(columns = ['Total employees'], axis = 1).copy()
pctchange = pergrowth_df.iloc[:, 1:].pct_change(axis =1)
pctchange['Industry'] = pd.Series(pergrowth_df['Industry'])
pctchange['%growth'] = (pctchange.drop('Industry', axis=1).sum(axis=1))* 100
pctchange
# Out:
#     2009      2010      2011      2012      2013      2014      2015  \
# 1    NaN  0.013263 -0.054974  0.000000  0.019391  0.160326 -0.046838
# 2    NaN -0.044033  0.058745 -0.026482  0.063472  0.055420 -0.005770
# 3    NaN -0.035197 -0.034335  0.014444 -0.021906  0.086226 -0.045361
# 4    NaN -0.002606 -0.004064  0.012241 -0.006335 -0.022602  0.060480
# 5    NaN  0.003597 -0.053763  0.030303 -0.011029  0.327138 -0.327731
# 6    NaN -0.118343  0.114094 -0.063253  0.041801  0.000000 -0.049383
# 7    NaN  0.081481  0.205479  0.068182 -0.042553  0.233333 -0.139640
# 8    NaN  0.006906 -0.015089 -0.043872  0.091770  0.020013  0.086985
# 9    NaN  0.007218  0.016722 -0.010808  0.014252  0.001405 -0.010290
# 10   NaN  0.059190  0.064706  0.005525  0.037088 -0.029139  0.053206
#
#         2016      2017      2018                        Industry    %growth
# 1   0.061425 -0.069444  0.022388                     Agriculture  10.553572
# ...

# %%
plt.rcParams['figure.figsize'] = [14,20]
plt.pie(x = pctchange['%growth'], labels= pergrowth_df['Industry'],autopct='%.2f %%')
plt.title("Percentage growth of industries over the period")
plt.show()

# %%
bywy = df1.drop(['Industry','Total employees'],axis =1).sum(axis = 0)
bywy
# Out:
# 2009    1336100
# 2010    1330400
# 2011    1346600
# 2012    1337300
# 2013    1365100
# 2014    1394400
# 2015    1403800
# 2016    1408800
# 2017    1422900
# 2018    1452200
# dtype: int64

# %%
#Year wise total employees
plt.rcParams['figure.figsize'] = [14,8]
yearTE = df1.drop(['Industry','Total employees'],axis =1).sum(axis = 0)
yearTE.plot(kind='line')
plt.xlabel("Year")
plt.ylabel("Count of employes")
plt.title("Total number of employess for each year")
plt.grid(True)

# %%
plt.rcParams['figure.figsize'] = [14,8]
yearTE = df1.drop(['Industry','Total employees'],axis =1).sum(axis = 0)
yearTE.plot(kind='bar')
plt.xlabel("Year")
plt.ylabel("Count of employes")
plt.title("Total number of employess for each year")
plt.grid(True)

# %% [markdown]
# #K-Means

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler
years=["2010","2018"]
create=df1[years]
solutions_set=create.rename(columns={'2010':'Bad','2018':'Good'})
scaler = MinMaxScaler()
solutions_set_scaled = scaler.fit_transform(solutions_set)
solutions_set_scaled = pd.DataFrame(solutions_set_scaled, columns = solutions_set.columns)
solutions_set_scaled
# Out:
#         Bad      Good
# 0  0.058416  0.038809
# 1  0.334653  0.342934
# 2  0.194554  0.186966
# 3  0.816584  0.786917
# 4  0.032921  0.015377
# 5  0.037624  0.025140
# 6  0.000000  0.000000
# 7  0.324752  0.395167
# 8  1.000000  1.000000
# 9  0.132178  0.138150

# %%
from sklearn.cluster import KMeans

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
plt.rcParams['figure.figsize'] = [14,8]
solutions_set_scaled,y= make_blobs(n_samples=300, centers=4, cluster_std=0.60, random_state=0)
plt.scatter(solutions_set_scaled[:,0], solutions_set_scaled[:,1])

wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
    kmeans.fit(solutions_set_scaled)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %% [markdown]
# #k=2

# %%
km = KMeans(n_clusters = 2, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 42)
y_means = km.fit_predict(solutions_set_scaled)
plt.rcParams['figure.figsize'] = [14,8]
plt.scatter(solutions_set_scaled[y_means == 0, 0], solutions_set_scaled[y_means == 0, 1], s = 100, c = 'pink', label = 'cluster1')
plt.scatter(solutions_set_scaled[y_means == 1, 0], solutions_set_scaled[y_means == 1, 1], s = 100, c = 'yellow', label = 'cluster2')
plt.scatter(km.cluster_centers_[:,0], km.cluster_centers_[:, 1], s = 50, c = 'blue' , label = 'centeroid')

plt.title('K Means Clustering')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.legend()
plt.grid()
plt.show();

# %% [markdown]
# #K=3

# %%
km = KMeans(n_clusters = 3, init = 'k-means++', max_iter = 300, n_init = 10, random_state = 42)
y_means = km.fit_predict(solutions_set_scaled)
plt.rcParams['figure.figsize'] = [14,8]
plt.scatter(solutions_set_scaled[y_means == 0, 0], solutions_set_scaled[y_means == 0, 1], s = 100, c = 'pink', label = 'cluster1')
plt.scatter(solutions_set_scaled[y_means == 1, 0], solutions_set_scaled[y_means == 1, 1], s = 100, c = 'yellow', label = 'cluster2')
plt.scatter(solutions_set_scaled[y_means == 2, 0], solutions_set_scaled[y_means == 2, 1], s = 100, c = 'green', label = 'cluster3')
plt.scatter(km.cluster_centers_[:,0], km.cluster_centers_[:, 1], s = 50, c = 'blue' , label = 'centeroid')

plt.title('K Means Clustering')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.legend()
plt.grid()
plt.show();

# %%
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
# Generating the sample data from make_blobs
# This particular setting has one distinct cluster and 3 clusters placed close
# together.
solutions_set_scaled, y = make_blobs(n_samples=500,
                  n_features=2,
                  centers=4,
                  cluster_std=1,
                  center_box=(-10.0, 10.0),
                  shuffle=True,
                  random_state=1)  # For reproducibility

range_n_clusters = [2, 3]

# %% [markdown]
# Elbow Method

# %%
from sklearn.cluster import KMeans

wcss=[]
for i in range(1,11):
    kmeans=KMeans(n_clusters=i, init='k-means++',random_state=0)
    kmeans.fit(solutions_set_scaled)
    wcss.append(kmeans.inertia_)

plt.plot(range(1,11),wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()

# %% [markdown]
# Cluster Labels

# %%
clusterer = KMeans(n_clusters=4, random_state=10)
cluster_labels = clusterer.fit_predict(solutions_set_scaled)
print(cluster_labels)
# Out:
# [2 2 3 1 0 1 0 0 0 0 2 2 0 1 0 2 0 2 1 0 3 3 0 1 0 0 1 1 3 0 2 1 0 2 0 2 3
#  3 2 3 0 3 1 0 0 2 3 0 1 1 1 3 3 0 2 3 3 3 3 0 1 1 3 0 1 0 2 0 3 3 2 3 0 2
#  0 0 2 0 0 3 1 1 3 1 1 3 3 1 3 3 1 2 3 0 1 2 2 0 2 1 1 2 1 3 1 0 0 1 1 3 0
#  2 1 3 1 3 1 0 1 0 3 2 2 3 0 3 1 2 2 0 1 3 3 3 3 2 1 0 1 1 0 2 0 1 1 1 0 0
#  2 2 3 3 1 2 1 3 3 3 3 3 3 3 3 3 1 2 2 2 0 1 2 3 0 2 1 3 3 3 3 2 0 3 1 2 2
#  3 0 2 2 0 1 1 2 2 0 1 0 2 2 1 2 3 1 0 0 2 0 3 2 0 3 0 3 2 0 0 0 1 3 1 0 2
#  3 0 3 3 3 1 3 1 2 3 2 3 1 1 3 2 1 2 0 3 2 2 2 2 0 3 2 3 0 1 1 0 0 1 3 0 3
#  1 0 1 3 3 1 0 2 2 3 3 3 0 1 1 0 1 3 2 1 2 1 2 2 1 2 1 1 0 3 3 3 0 0 3 2 1
#  2 2 2 0 3 0 2 3 2 2 3 2 2 3 1 2 0 0 1 1 3 2 1 1 0 2 1 1 0 3 1 3 0 2 2 1 3
#  2 0 1 1 0 0 0 2 0 1 1 3 1 1 1 1 2 2 0 1 3 0 2 1 3 1 0 1 3 0 3 1 0 0 2 1 2
#  2 2 2 2 2 3 2 1 2 1 1 3 1 0 3 3 2 1 3 1 0 2 3 3 2 3 3 1 1 2 3 0 1 0 0 2 2
#  0 2 3 3 2 3 2 3 1 2 1 3 0 1 3 0 1 2 0 1 1 3 0 3 0 2 1 2 0 1 2 2 2 3 1 0 2
# ...

# %% [markdown]
# K means clustering for K=2 and K=3 and silhoutee coefficient

# %%
import matplotlib.cm as cm
import numpy as np
for n_clusters in range_n_clusters:

    fig, (ax1, ax2) = plt.subplots(1, 2)
    fig.set_size_inches(18, 7)
    ax1.set_xlim([-0.1, 1])
    ax1.set_ylim([0, len(solutions_set_scaled) + (n_clusters + 1) * 10])
    clusterer = KMeans(n_clusters=n_clusters, random_state=10)
    cluster_labels = clusterer.fit_predict(solutions_set_scaled)
    silhouette_avg = silhouette_score(solutions_set_scaled, cluster_labels)
    print("For n_clusters =", n_clusters,
          "The average silhouette_score is :", silhouette_avg)

    sample_silhouette_values = silhouette_samples(solutions_set_scaled, cluster_labels)

    y_lower = 10
    for i in range(n_clusters):
        ith_cluster_silhouette_values = \
            sample_silhouette_values[cluster_labels == i]

        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        color = cm.nipy_spectral(float(i) / n_clusters)
        ax1.fill_betweenx(np.arange(y_lower, y_upper),
                          0, ith_cluster_silhouette_values,
                          facecolor=color, edgecolor=color, alpha=0.7)

        ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))
        y_lower = y_upper + 10  # 10 for the 0 samples

    ax1.set_title("The silhouette plot for the various clusters.")
    ax1.set_xlabel("The silhouette coefficient values")
    ax1.set_ylabel("Cluster label")

    # The vertical line for average silhouette score of all the values
    ax1.axvline(x=silhouette_avg, color="red", linestyle="--")

    ax1.set_yticks([])  # Clear the yaxis labels / ticks
    ax1.set_xticks([-0.1, 0, 0.2, 0.4, 0.6, 0.8, 1])

    # 2nd Plot showing the actual clusters formed
    colors = cm.nipy_spectral(cluster_labels.astype(float) / n_clusters)
    ax2.scatter(solutions_set_scaled[:, 0], solutions_set_scaled[:, 1], marker='.', s=30, lw=0, alpha=0.7,
                c=colors, edgecolor='k')

       # Labeling the clusters
    centers = clusterer.cluster_centers_
    # Draw white circles at cluster centers
    ax2.scatter(centers[:, 0], centers[:, 1], marker='o',
                c="white", alpha=1, s=200, edgecolor='k')

    for i, c in enumerate(centers):
        ax2.scatter(c[0], c[1], marker='$%d$' % i, alpha=1,
                    s=50, edgecolor='k')

    ax2.set_title("The visualization of the employment clusterd data.")
    ax2.set_xlabel("Feature space for the 1st feature")
    ax2.set_ylabel("Feature space for the 2nd feature")

    plt.suptitle(("Silhouette analysis for KMeans clustering on employment data "
                  "with n_clusters = %d" % n_clusters),
                 fontsize=14, fontweight='bold')

plt.show()
# Out:
# For n_clusters = 2 The average silhouette_score is : 0.7049787496083262
# For n_clusters = 3 The average silhouette_score is : 0.5882004012129721

# %%
# kendall correlation between the submissions
plt.figure(figsize=(10, 6))
kendall = solutions_set.corr(method = 'kendall')
sns.heatmap(kendall, annot = True, fmt = ".3f")
plt.title('Kendall correlation')
# Out:
# Text(0.5, 1.0, 'Kendall correlation')
